# %% [markdown]
# ## Código 3 — Diagnóstico del residuo por fracción difusa
#
# Este código analiza el error del modelo NOCT usando la base generada en el Código 2.
#
# Primero filtra las horas válidías para modelado. Luego calcula métricas globales y por régimen de fracción difusa (`baja_fd`, `mixto`, `alta_fd`), incluyendo MAE, RMSE, bias, R² y error relativo promedio.
#
# También calcula la correlación entre `fd` y el error del modelo, y genera gráficos para visualizar:
#
# - residuo `epsilon` vs `fd`;
# - error absoluto por régimen;
# - error relativo por régimen;
# - comparación entre `P_NOCT` y `P_ref`.
#
# El objetivo es evaluar si el error del modelo físico cambia según la fracción difusa antes de entrenar el modelo híbrido.

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


INPUT_FILE = Path("data/02_noct_vs_pvwatts_rancagua.csv")

OUT_DIR = Path("outputs/03_diagnostico_fd_rancagua")
OUT_DIR.mkdir(parents=True, exist_ok=True)

METRICS_GLOBAL_FILE = OUT_DIR / "metricas_globales_rancagua.csv"
METRICS_REGIMEN_FILE = OUT_DIR / "metricas_por_regimen_fd_rancagua.csv"
CORRELATIONS_FILE = OUT_DIR / "correlaciones_fd_error_rancagua.csv"

REGIMEN_ORDER = ["baja_fd", "mixto", "alta_fd"]



def rmse(y_true, y_pred):
    return np.sqrt(np.mean((y_true - y_pred) ** 2))


def mae(y_true, y_pred):
    return np.mean(np.abs(y_true - y_pred))


def bias(y_true, y_pred):
    # positivo = NOCT sobreestima si usamos pred - true
    return np.mean(y_pred - y_true)


def r2_score_manual(y_true, y_pred):
    ss_res = np.sum((y_true - y_pred) ** 2)
    ss_tot = np.sum((y_true - np.mean(y_true)) ** 2)

    if ss_tot == 0:
        return np.nan

    return 1 - ss_res / ss_tot


def calculate_metrics(df):
    y_true = df["p_ref_dc"]
    y_pred = df["p_noct"]

    return {
        "n": len(df),
        "MAE_W": mae(y_true, y_pred),
        "RMSE_W": rmse(y_true, y_pred),
        "Bias_W": bias(y_true, y_pred),
        "R2": r2_score_manual(y_true, y_pred),
        "Error_relativo_promedio": df["relative_error"].mean(),
        "P_ref_promedio_W": y_true.mean(),
        "P_NOCT_promedio_W": y_pred.mean(),
        "fd_promedio": df["fd"].mean(),
    }



def load_data():
    if not INPUT_FILE.exists():
        raise FileNotFoundError(
            f"No se encontró el archivo {INPUT_FILE}. "
            "Primero ejecuta el Código 2 para Rancagua."
        )

    df = pd.read_csv(INPUT_FILE)

    required_columns = [
        "fd",
        "regimen_fd",
        "p_ref_dc",
        "p_noct",
        "epsilon",
        "abs_epsilon",
        "relative_error",
        "is_valid_model",
    ]

    missing = [col for col in required_columns if col not in df.columns]

    if missing:
        raise ValueError(f"Faltan columnas requeridas: {missing}")

    if df["is_valid_model"].dtype == "object":
        df["is_valid_model"] = df["is_valid_model"].astype(str).str.lower() == "true"

    df["regimen_fd"] = pd.Categorical(
        df["regimen_fd"],
        categories=REGIMEN_ORDER,
        ordered=True,
    )

    df_valid = df[df["is_valid_model"]].copy()

    df_valid = df_valid.dropna(
        subset=[
            "fd",
            "regimen_fd",
            "p_ref_dc",
            "p_noct",
            "epsilon",
            "abs_epsilon",
            "relative_error",
        ]
    )

    return df, df_valid



def build_metrics_tables(df_valid):
    metrics_global = pd.DataFrame([calculate_metrics(df_valid)])
    metrics_global.to_csv(METRICS_GLOBAL_FILE, index=False)

    rows = []

    for regimen in REGIMEN_ORDER:
        group = df_valid[df_valid["regimen_fd"] == regimen].copy()

        if len(group) == 0:
            continue

        row = calculate_metrics(group)
        row["regimen_fd"] = regimen
        rows.append(row)

    metrics_regimen = pd.DataFrame(rows)

    cols = ["regimen_fd"] + [c for c in metrics_regimen.columns if c != "regimen_fd"]
    metrics_regimen = metrics_regimen[cols]

    metrics_regimen.to_csv(METRICS_REGIMEN_FILE, index=False)

    return metrics_global, metrics_regimen


def build_correlations(df_valid):
    correlations = []

    variables_error = ["epsilon", "abs_epsilon", "relative_error"]

    for var in variables_error:
        pearson = df_valid["fd"].corr(df_valid[var], method="pearson")
        spearman = df_valid["fd"].corr(df_valid[var], method="spearman")

        correlations.append({
            "variable_error": var,
            "corr_pearson_con_fd": pearson,
            "corr_spearman_con_fd": spearman,
        })

    corr_df = pd.DataFrame(correlations)
    corr_df.to_csv(CORRELATIONS_FILE, index=False)

    return corr_df



def plot_epsilon_vs_fd(df_valid):
    plt.figure(figsize=(8, 5))
    plt.scatter(df_valid["fd"], df_valid["epsilon"], s=8, alpha=0.35)
    plt.axhline(0, linestyle="--", linewidth=1)

    plt.xlabel("Fracción difusa fd")
    plt.ylabel("Residuo epsilon = P_ref - P_NOCT [W]")
    plt.title("Rancagua: residuo del modelo NOCT vs fracción difusa")
    plt.tight_layout()

    plt.savefig(OUT_DIR / "scatter_epsilon_vs_fd_rancagua.png", dpi=300)
    plt.close()


def plot_abs_error_by_regimen(df_valid):
    data = [
        df_valid.loc[df_valid["regimen_fd"] == reg, "abs_epsilon"]
        for reg in REGIMEN_ORDER
    ]

    plt.figure(figsize=(8, 5))
    plt.boxplot(data, tick_labels=REGIMEN_ORDER, showfliers=False)

    plt.xlabel("Régimen de fracción difusa")
    plt.ylabel("Error absoluto |epsilon| [W]")
    plt.title("Rancagua: error absoluto del NOCT por régimen fd")
    plt.tight_layout()

    plt.savefig(OUT_DIR / "boxplot_abs_error_por_regimen_rancagua.png", dpi=300)
    plt.close()


def plot_relative_error_by_regimen(df_valid):
    data = [
        df_valid.loc[df_valid["regimen_fd"] == reg, "relative_error"] * 100
        for reg in REGIMEN_ORDER
    ]

    plt.figure(figsize=(8, 5))
    plt.boxplot(data, tick_labels=REGIMEN_ORDER, showfliers=False)

    plt.xlabel("Régimen de fracción difusa")
    plt.ylabel("Error relativo [%]")
    plt.title("Rancagua: error relativo del NOCT por régimen fd")
    plt.tight_layout()

    plt.savefig(OUT_DIR / "boxplot_error_relativo_por_regimen_rancagua.png", dpi=300)
    plt.close()


def plot_pred_vs_ref(df_valid):
    plt.figure(figsize=(6, 6))
    plt.scatter(df_valid["p_ref_dc"], df_valid["p_noct"], s=8, alpha=0.35)

    max_val = max(df_valid["p_ref_dc"].max(), df_valid["p_noct"].max())
    plt.plot([0, max_val], [0, max_val], linestyle="--", linewidth=1)

    plt.xlabel("P_ref PVWatts DC [W]")
    plt.ylabel("P_NOCT [W]")
    plt.title("Rancagua: comparación P_NOCT vs P_ref")
    plt.tight_layout()

    plt.savefig(OUT_DIR / "scatter_pnoct_vs_pref_rancagua.png", dpi=300)
    plt.close()


def plot_mae_by_regimen(metrics_regimen):
    metrics_regimen = metrics_regimen.copy()
    metrics_regimen["regimen_fd"] = pd.Categorical(
        metrics_regimen["regimen_fd"],
        categories=REGIMEN_ORDER,
        ordered=True,
    )
    metrics_regimen = metrics_regimen.sort_values("regimen_fd")

    plt.figure(figsize=(8, 5))
    plt.bar(metrics_regimen["regimen_fd"].astype(str), metrics_regimen["MAE_W"])

    plt.xlabel("Régimen de fracción difusa")
    plt.ylabel("MAE [W]")
    plt.title("Rancagua: MAE del modelo NOCT por régimen fd")
    plt.tight_layout()

    plt.savefig(OUT_DIR / "bar_mae_por_regimen_rancagua.png", dpi=300)
    plt.close()



def main():
    print("Leyendo datos...")
    df, df_valid = load_data()

    print("\nFilas totales:")
    print(len(df))

    print("\nFilas válidías para diagnóstico:")
    print(len(df_valid))

    print("\nConteo por régimen fd:")
    print(df_valid["regimen_fd"].value_counts().sort_index())

    print("\nCalculando métricas...")
    metrics_global, metrics_regimen = build_metrics_tables(df_valid)

    print("\nMétricas globales:")
    print(metrics_global.round(4).to_string(index=False))

    print("\nMétricas por régimen fd:")
    print(metrics_regimen.round(4).to_string(index=False))

    print("\nCalculando correlaciones...")
    corr_df = build_correlations(df_valid)

    print("\nCorrelaciones fd vs error:")
    print(corr_df.round(4).to_string(index=False))

    print("\nGenerando gráficos...")
    plot_epsilon_vs_fd(df_valid)
    plot_abs_error_by_regimen(df_valid)
    plot_relative_error_by_regimen(df_valid)
    plot_pred_vs_ref(df_valid)
    plot_mae_by_regimen(metrics_regimen)

    print("\nArchivos generados en:")
    print(OUT_DIR)

    print("\nTablas:")
    print(METRICS_GLOBAL_FILE)
    print(METRICS_REGIMEN_FILE)
    print(CORRELATIONS_FILE)

    print("\nGráficos:")
    for file in OUT_DIR.glob("*.png"):
        print(file)


if __name__ == "__main__":
    main()
# Out:
# Leyendo datos...
#
# Filas totales:
# 8760
#
# Filas validas para diagnóstico:
# 3688
#
# Conteo por régimen fd:
# regimen_fd
# baja_fd    1349
# mixto      1124
# alta_fd    1215
# Name: count, dtype: int64
#
# Calculando métricas...
#
# Métricas globales:
#    n   MAE_W  RMSE_W  Bias_W     R2  Error_relativo_promedio  P_ref_promedio_W  P_NOCT_promedio_W  fd_promedio
# 3688 12.0806 16.0186 -2.3834 0.9958                   0.0372          414.8076           412.4242       0.5218
#
# Métricas por régimen fd:
# regimen_fd    n   MAE_W  RMSE_W   Bias_W     R2  Error_relativo_promedio  P_ref_promedio_W  P_NOCT_promedio_W  fd_promedio
#    baja_fd 1349 20.4243 23.9702 -14.5404 0.9589                   0.0298          673.9032           659.3628       0.1960
#      mixto 1124  7.8832  9.6702   2.4999 0.9967                   0.0307          362.0676           364.5676       0.4869
#    alta_fd 1215  6.6995  7.3769   6.5968 0.9953                   0.0515          175.9268           182.5236       0.9158
#
# Calculando correlaciones...
#
# Correlaciones fd vs error:
# variable_error  corr_pearson_con_fd  corr_spearman_con_fd
#        epsilon              -0.5686               -0.5856
#    abs_epsilon              -0.5315               -0.5263
# relative_error               0.3590                0.3119
#
# Generando gráficos...
#
# Archivos generados en:
# outputs\03_diagnostico_fd_rancagua
#
# Tablas:
# outputs\03_diagnostico_fd_rancagua\metricas_globales_rancagua.csv
# outputs\03_diagnostico_fd_rancagua\metricas_por_regimen_fd_rancagua.csv
# outputs\03_diagnostico_fd_rancagua\correlaciones_fd_error_rancagua.csv
#
# Gráficos:
# outputs\03_diagnostico_fd_rancagua\bar_mae_por_regimen_rancagua.png
# outputs\03_diagnostico_fd_rancagua\boxplot_abs_error_por_regimen_rancagua.png
# outputs\03_diagnostico_fd_rancagua\boxplot_error_relativo_por_regimen_rancagua.png
# outputs\03_diagnostico_fd_rancagua\scatter_epsilon_vs_fd_rancagua.png
# outputs\03_diagnostico_fd_rancagua\scatter_pnoct_vs_pref_rancagua.png
